# %% [markdown]
# *Importing Libraries*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# *Importing CSV File*

# %%
file_path = 'CrashReport.csv'
data = pd.read_csv(file_path, index_col = 0)

# %% [markdown]
# *Exploratory Data Analysis*

# %%
data.head()
# Out:
#                                 2022   2021   2020   2019   2018   2017  \
# colname
# NaN                              NaN    NaN    NaN    NaN    NaN    NaN
# Motor Vehicle Traffic Crashes      -      -      -      -      -      -
# Fatal Crashes                  39221  39785  35935  33487  33919  34560
# Traffic Crash Fatalities           -      -      -      -      -      -
# Vehicle Occupants                  -      -      -      -      -      -
#
#                                 2016   2015   2014   2013  ...   2002   2001  \
# colname                                                    ...
# NaN                              NaN    NaN    NaN    NaN  ...    NaN    NaN
# Motor Vehicle Traffic Crashes      -      -      -      -  ...      -      -
# Fatal Crashes                  34748  32538  30056  30202  ...  38491  37862
# Traffic Crash Fatalities           -      -      -      -  ...      -      -
# ...

# %%
data.describe()
# Out:
#         isHeader
# count  25.000000
# mean    0.320000
# std     0.476095
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     1.000000
# max     1.000000

# %%
print(data.isnull().sum())
# Out:
# 2022        1
# 2021        1
# 2020        1
# 2019        1
# 2018        1
# 2017        1
# 2016        1
# 2015        1
# 2014        1
# 2013        1
# 2012        1
# 2011        1
# 2010        1
# 2009        1
# 2008        1
# 2007        1
# 2006        1
# 2005        1
# 2004        1
# 2003        1
# 2002        1
# 2001        1
# 2000        1
# 1999        1
# 1998        1
# 1997        1
# 1996        1
# 1995        1
# 1994        1
# isHeader    1
# dtype: int64

# %%
data.replace('-', np.nan, inplace = True)
data = data.dropna()

# %%
data.describe()
# Out:
#         isHeader
# count  19.000000
# mean    0.105263
# std     0.315302
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.000000
# max     1.000000

# %% [markdown]
# *Renaming indexes for cleaning purposes*

# %%
data = data.rename(index = {'&nbsp;&nbsp;Motorcyclists' : 'Motorcyclists'})

# %%
data = data.rename(index = {'Unknown' : 'Unknown1', 'Other/ Unknown' : 'Unknown2', 'Total*' : 'Total'})

# %% [markdown]
# *Transposing Database to flip **Rows** with **Cloumns***

# %%
data = data.transpose()
# Out:
# colname  Fatal Crashes Drivers Passengers Unknown1 Sub Total1 Motorcyclists  \
# 2022             39221   20908       6393       43      27344          6218
# 2021             39785   21716       6580       43      28339          6143
# 2020             35935   19552       6011       54      25617          5620
# 2019             33487   17984       5846       61      23891          5044
# 2018             33919   18321       5962       49      24332          5038
# 2017             34560   18819       6237       74      25130          5226
# 2016             34748   18717       6485       74      25276          5337
# 2015             32538   17615       6213       71      23899          5029
# 2014             30056   16470       5766       71      22307          4594
# 2013             30202   16520       5896       67      22483          4692
# 2012             31006   16838       6106       73      23017          4986
# ...

# %%
data = data.drop(data.index[-1])

# %% [markdown]
# *Saving the modified CSV into a new CSV file*

# %%
data.to_csv('modified_CrashReport.csv', index = True)
